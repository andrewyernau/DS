# %% [markdown]
# # Visualización de datos

# %% [markdown]
# Existen varias librerías populares de visualización de datos, siendo la principal `matplotlib`

# %%
from IPython import display
display.Image('https://multimediarepository.blob.core.windows.net/imagecontainer/956077a0a5f74a3b81d2aa3fbb302f56.png')

# %% [markdown]
# ## [https://matplotlib.org/](https://matplotlib.org/)

# %% [markdown]
# # `matplotlib` permite a través de la programación crear todo tipo de gráficas y personalizar cualquiera de sus aspectos.
#
# - Permite crear gráficas de alta calidad.
# - Permite interactuar con ellas (zoom, actualizar)
# - Permite controlar los estilos de líneas, de marcadores, de fuentes, las propiedades de los ejes, las etiquetas
# - Permite exportar la gráfica a muchos formatos de ficheros

# %% [markdown]
# # Este control muy fino permite gráficas realmente espectaculares.

# %% [markdown]
# ## Entre las mejores, sin duda: [https://github.com/rougier/scientific-visualization-book](https://github.com/rougier/scientific-visualization-book)

# %% [markdown]
# ## Un gráfica reciente llamada bump chart, Premier League [https://twitter.com/utdmaram/status/1349117512248664071?s=20](https://twitter.com/utdmaram/status/1349117512248664071?s=20)
# ## Órbitas: https://x.com/matplotlib/status/1762446737141039311?s=20

# %% [markdown]
# ## Algún ejemplos de animación:
# - [https://twitter.com/SilverJacket/status/1348290841073299459?s=20](https://twitter.com/SilverJacket/status/1348290841073299459?s=20)
# - [https://twitter.com/camminady/status/1350407474558464001?s=20](https://twitter.com/camminady/status/1350407474558464001?s=20)

# %% [markdown]
# > Podéis encontrar muchos ejemplos en [@matplotlib](https://twitter.com/matplotlib)

# %% [markdown]
# ## Pero la curva de aprendizaje es muy empinada...

# %% [markdown]
# > Nosotros veremos unos principios básicos, y recurriremos a algunas funciones de visualización en `pandas` así como a la librería `seaborn` ambas construidas con `matplotlib` pero que facilitan la exploración rápida de conjuntos de datos.

# %% [markdown]
# > Un recurso muy útil: las "cheatsheets" oficiales de `matplotlib', disponibles en:
# [https://github.com/matplotlib/cheatsheets/](https://github.com/matplotlib/cheatsheets/)

# %% [markdown]
# ## Gráficas básicas en `matplotlib`

# %% [markdown]
# `matplotlib` presenta una jerarquía de los distintos elementos de una gráfica:
#
# Sus elementos principales son:
# - `figure`: la figura completa que puede contener diferentes gráficas
# - `axes`: lo que normalmente entendemos por gráfica.
# - `axis`: los ejes de cada gráfica
# - `artist`: todo lo que se ve en una figura es un `artist`, incluso `figure`, `axes`, `axis`.

# %%
display.Image(
    "https://multimediarepository.blob.core.windows.net/imagecontainer/c2f81bb3bda0465c81094f210283fa6b.png",
    width = 200, height = 200)

# %% [markdown]
# ## El primer paso consiste en importar pyplot del módulo `matplotlib`

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Empezaremos por crear el elemento `figure` y su o sus `axes` (gráficas)
# Para ello, usaremos la instrucción `subplots`

# %%
fig, ax = plt.subplots()
ax.set_title('Mi gráfica')
# Out:
# Text(0.5, 1.0, 'Mi gráfica')

# %% [markdown]
# Podemos especificar una matriz de `axes`: por ejemplo una fila y dos columnas

# %%
fig, axs = plt.subplots(1,2)

# %% [markdown]
# Ahora añadimos elementos al objeto `ax` o a cada componente de `axs`, `axs[0]` o `axs[1]`, aplicandoles métodos, por ejemplo, añadiendo un título:

# %%
fig, axs = plt.subplots(1,2)
axs[0].set_title('Primera gráfica');
axs[1].set_title('Segunda gráfica');

# %% [markdown]
# Consideremos unos datos sencillos

# %%
import pandas as pd
df = pd.DataFrame({
    'col1': [3, 1, 5],
    'col2': [2, 4, 6],
    'col3': ['a', 'b', 'c'],
    'col4': ['Hombre', 'Mujer', 'Hombre'],
    'col5': [100, 300, 200]
    }
)
df.sort_values('col1', inplace=True)
df
# Out:
#    col1  col2 col3    col4  col5
# 1     1     4    b   Mujer   300
# 0     3     2    a  Hombre   100
# 2     5     6    c  Hombre   200

# %% [markdown]
# Vamos a crear un `figure` con un único `axes`, y representar `col2` en función de `col1`

# %%
fig,ax = plt.subplots()
ax.plot(df['col1'], df['col2']);

# %% [markdown]
# El método `plot` representa líneas que unen los puntos por orden de aparición en los vectores `df['col1']` y `df['col2']`.

# %% [markdown]
# Otros métodos que se aplican a un `axes` representan otros tipos de gráficas:

# %%
fig,ax = plt.subplots()
ax.scatter(df['col1'], df['col2']);

# %%
fig,ax = plt.subplots()
ax.bar(df['col1'], df['col2']);

# %%
fig,ax = plt.subplots()
ax.fill(df['col1'], df['col2']);

# %%
fig,ax = plt.subplots()
ax.fill_between(df['col1'], df['col2']);

# %% [markdown]
# ## Para fijar algunos aspectos de la representación gráfica

# %% [markdown]
# ### Podemos fijar el color de los marcadores, las barras o las líneas.

# %%
fig, ax = plt.subplots()
ax.scatter(df['col1'], df['col2'], color='salmon');

# %% [markdown]
# > El control de los colores en `matplotlib` es muy extenso, por una parte, se puede consultar la lista de nombres de colores soportados en [https://matplotlib.org/3.3.3/gallery/color/named_colors.html](https://matplotlib.org/3.3.3/gallery/color/named_colors.html)
# Por otra parte, se pueden usar "colormaps", para disponer de colores de variación uniforme. Más información más adelante.

# %% [markdown]
# ## Podemos fijar el tipo de marcadores

# %%
fig, ax = plt.subplots()
ax.scatter(df['col1'], df['col2'], color='salmon',marker='P');

# %% [markdown]
#  Ver los marcadores posibles en la cheatsheet: [https://github.com/matplotlib/cheatsheets/](https://github.com/matplotlib/cheatsheets/) de la que está extraida la siguiente imagen:

# %%
display.Image('https://multimediarepository.blob.core.windows.net/imagecontainer/b87c7d67ed61450da7e4fef888e00860.png')

# %% [markdown]
# ## Podemos fijar el tipo de líneas y su grosor

# %% [markdown]
# Extraido de la cheatsheet [https://github.com/matplotlib/cheatsheets/](https://github.com/matplotlib/cheatsheets/):

# %%
display.Image('https://multimediarepository.blob.core.windows.net/imagecontainer/eb1d23f2926041b4a8292b1d0378c09a.png')

# %%
fig, ax = plt.subplots()
ax.plot(df['col1'], df['col2'], linestyle='--');

# %% [markdown]
# ## Podemos combinar marcadores y líneas:

# %%
fig, ax = plt.subplots()
ax.plot(df['col1'], df['col2'], linestyle='--',linewidth=3,marker='P');

# %% [markdown]
# # Todos los elementos de una figura son modificables
# Para ello, existen una gran variedad de métodos que se aplican a `figure` o `axes` o a sus elementos.

# %% [markdown]
# Nos fijamos por ejemplo en los básicos mencionados en la [cheatsheet](https://github.com/matplotlib/cheatsheets/blob/master/cheatsheets-1.png)

# %%
ax.grid() # Para añadir una rejilla
ax.set_xlim(vmin, vmax) # fija los límites del eje Ox, igual para set_ylim
ax.set_xlabel(label) # Establece la etiqueta del eje Ox, igual para Oy
ax.set_xticks(list) # indica en qué valores debe aparecer "ticks" en Ox, igual para Oy
ax.set_ticklabels(list) # indica las etiquetas de los "ticks" en Ox, igual en Oy
ax.set_title(title) # Indica el título de la gráfica
ax.set_tick_params(width=10) # fija diferentes parámetros por ejemplo rotation, se puede especificar axis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 ax.grid() # Para añadir una rejilla
# ----> 2 ax.set_xlim(vmin, vmax) # fija los límites del eje Ox, igual para set_ylim
#       3 ax.set_xlabel(label) # Establece la etiqueta del eje Ox, igual para Oy
#       4 ax.set_xticks(list) # indica en qué valores debe aparecer "ticks" en Ox, igual para Oy
#
# NameError: name 'vmin' is not defined

# %% [markdown]
# Para evitar solapamientos en las etiquetas de los ejes, los títulos, etc... podemos usar el método `tight_layout` que se aplica a un `axes` concreto o a todo un `figure`.

# %%
fig.tight_layout() # también podría ser ax.tight_layout()

# %% [markdown]
# El patch  es un rectángulo de un elemento geométrico con color de fondo y color de borde. Tanto `figure` como `axes` tienen patch. Podemos usar los métodos `set_facecolor`, `set_edgecolor` y `set_alpha` sobre un patch:

# %%
fig.patch.set_facecolor('green') # El patch

# %% [markdown]
# ## Intentad reproducir la figura siguiente

# %%
fig, ax = plt.subplots()
fig.tight_layout()

ax.patch.set_facecolor("#0000ff22")
ax.grid()
ax.set_title("Grafica Sencilla")
ax.set_xlabel("Primera Columna")
ax.set_ylabel("Segunda Columna")
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
ax.plot(df['col1'], df['col2'], linestyle='--',linewidth=1,marker='D');

# %% [markdown]
# ## Mapas de colores (`colormaps`) en `matplotlib`

# %% [markdown]
# Muy a menudo necesitamos un conjunto de colores para distinguir grupos de datos en la gráfica. `matplotlib` proporciona muchos mapas de colores diseñados para permitir visualizar de manera fidedigna la variación de una o varias cantidades.

# %% [markdown]
# Se puede consultar el [tutorial oficial](https://matplotlib.org/3.3.0/tutorials/colors/colormaps.html) y la cheatsheet presenta varios mapas de colores:

# %%
display.Image('https://multimediarepository.blob.core.windows.net/imagecontainer/9447b7e2e38a49e0a4bc9a93f705d715.png')

# %% [markdown]
# Si represento datos en una gráfica que corresponden a dos grupos diferentes, es bueno distinguirlos con colores diferentes o/y tipos de líneas diferentes, marcadores diferentes.

# %% [markdown]
# Por una parte, poder añadir tantos `ax.plot`, `ax.scatter` etc, como grupos:

# %%
import pandas as pd
import numpy as np
rng=np.random.default_rng(314)
df = pd.DataFrame(
    {'H':2*rng.integers(low=0,high=2,size=100)-1,
     'M':2*rng.integers(low=0,high=2,size=100)-1,}
    ).cumsum()
df

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots()
ax.step(df.index.values, df['H'])
ax.step(df.index.values, df['M']);

# %% [markdown]
# `matplotlib` se ha encargado de cambiar de color para cada `plot`.

# %% [markdown]
# Para que sea más informativo, puedo añadir una etiqueta a cada serie representada y generar una leyenda:

# %%
fig, ax = plt.subplots()
ax.step(df.index.values, df['H'],label='Hombres');
ax.step(df.index.values, df['M'],label='Mujeres');
ax.legend();

# %% [markdown]
# A medida que voy añadiendo elementos, `matplotlib` recorre un ciclo de colores que por defecto es el siguiente: (imagen extraida de https://matplotlib.org/3.2.1/users/dflt_style_changes.html#colors-in-default-property-cycle)

# %%
display.Image('https://multimediarepository.blob.core.windows.net/imagecontainer/331c53812936422fbdf74dd038ee4c9b.png')

# %% [markdown]
# También es posible especificar el color en cada serie, por supuesto

# %%
fig, ax = plt.subplots()
ax.step(df.index.values, df['H'],label='Hombres', color='red');
ax.step(df.index.values, df['M'],label='Mujeres', color='blue');
ax.legend();

# %% [markdown]
# A menudo usamos el color para visualizar la variación de una variable, podéis pensar en un "heatmap" por ejemplo. (Fuente: http://www.wright.edu/~oleg.paliy/Papers/PCR_modeling/FigureS5.png)

# %%
display.Image(
    'https://multimediarepository.blob.core.windows.net/imagecontainer/a1c13e3e078746aaae48aa5e102e59f1.png',
    width=600,
    height=600)

# %% [markdown]
# Veamos cómo hacerlo en un scatter plot:

# %%
x = rng.standard_normal(size=300)
y = rng.standard_normal(size=300) * 3
z = rng.random(size=300)

# %%
fig,ax = plt.subplots()
ax.scatter(x, y, c=z);

# %% [markdown]
# Podemos añadir una barra de colores (`colorbar`):

# %%
fig,ax = plt.subplots()
p = ax.scatter(x, y, c=z);
fig.colorbar(p, ax=ax);

# %% [markdown]
# El mapa de colores que ha usado `matplotlib` por defecto es `viridis`

# %%
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))
fig, ax = plt.subplots()
ax.imshow(gradient, aspect='auto', cmap='viridis')
ax.set_axis_off();

# %% [markdown]
# Ha mapeado el rango de valores que toma la variable `z` con el rango de colores de `viridis`. El mínimo de `z` está asociado con el lila oscuro, mientras que el máximo está asociado con amarillo. El color de cualquier punto en medio está interpolado.

# %% [markdown]
# > Probad a cambiar el colormap, añadiendo el parámetro `cmap` en `ax.scatter`, por ejemplo, `cmap='Spectral'`

# %%
fig,ax = plt.subplots()
p = ax.scatter(x, y, c=z, cmap='Spectral');
fig.colorbar(p, ax=ax);

# %% [markdown]
# ## Para usar los colores de un colormap
# Hemos visto que `scatter` tenía un parámetro `cmap`, pero hay ocasiones en que queremos usar los colores de un colormap en otros contextos.

# %% [markdown]
# Empezamos por recuperar un colormap, por ejemplo `inferno`

# %%
clmap = plt.cm.get_cmap('inferno')
# Out:
# C:\Users\andrew\AppData\Local\Temp\ipykernel_4596\3878421031.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   clmap = plt.cm.get_cmap('inferno')

# %% [markdown]
# Hemos de ser conscientes de lo siguiente:
# - Un colormap está basado en un número de colores. En el caso de `inferno` es 256.
# - El objeto `clmap` que hemos definido realiza el mapeo se hace desde el intervalo de 0 a 1 hacia los colores del colormap.
# - Si necesito un número n de colores, lo más sencillo es pasarle a `clmap` el vector de n valores repartidos uniformemente entre 0 y 1. Puedo construir este vector con `np.linspace(0, 1, n)`

# %% [markdown]
# Podemos usar estos colores en cualquier elemento gráfico de un `ax`. Por ejemplo, supongamos que tenemos 15 series de caminatas aleatorias que recogemos en una lista

# %%
series = [np.cumsum(2 * rng.integers(low=0, high=2, size=100) - 1) for i in range(15)]

# %% [markdown]
# Vamos a representarlas, con funciones step y añadiendo una leyenda

# %%
fig, ax = plt.subplots(figsize=(15, 15))
for i,s in enumerate(series):
    ax.step(np.arange(0,100), s, label=f'Serie {i + 1}')
ax.legend();

# %% [markdown]
# Creamos un vector de colores, usando el colormap que hemos escogido:

# %%
clmp = plt.cm.get_cmap('inferno',15)
colores = clmp(np.linspace(0, 1, 15))
# Out:
# C:\Users\andrew\AppData\Local\Temp\ipykernel_4596\2547065332.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   clmp = plt.cm.get_cmap('inferno',15)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
for i,s in enumerate(series):
    ax.step(np.arange(0,100), s, label=f'Serie {i + 1}', color = colores[i])
ax.legend();

# %% [markdown]
# En este caso, clmap está basado en los 8 primeros colores del colormap 'Spectral'.
